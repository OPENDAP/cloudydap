# %% [markdown]
# Copyright (C) 2017 The HDF Group
#
# This example code illustrates how to access and visualize a GES DISC OCO-2
# Swath HDF5 file in Python via OPeNDAP.
#
# If you have any questions, suggestions, or comments on this example, please use
# the HDF-EOS Forum (http://hdfeos.org/forums).  If you would like to see an
# example of any other NASA HDF/HDF-EOS data product that is not listed in the
# HDF-EOS Comprehensive Examples page (http://hdfeos.org/zoo), feel free to
# contact us at eoshelp@hdfgroup.org or post it at the HDF-EOS Forum
# (http://hdfeos.org/forums).

# %%
import cesiumpy
from pydap.client import open_url, open_dods
from pydap.cas.urs import setup_session
# Replace username and passowrd to match yours.
session = setup_session('eoshelp', '******')

# %% [markdown]
# For some reason, GES DISC Hyrax server *doesn't work with PyDAP*.
# Thus, we'll use The HDF Group's demo server.

# %%
# Please use https for GES DISC server.
#
# FILE_NAME = 'oco2_L2StdGL_13568a_170118_B7302_170120063653.h5'
# url = 'https://oco2.gesdisc.eosdis.nasa.gov/opendap/OCO2_L2_Standard.7/2017/018/'+FILE_NAME
# dataset = open_url(url, session=session)


# This example works well with demo Hyrax server. 
url = 'https://eosdap.hdfgroup.org:8080/opendap/hyrax/data/NASAFILES/hdf5/oco2_L2StdND_03945a_150330_B6000_150331024816.h5'
dataset = open_url(url)


# This should print all datasets available from the OPeNDAP url.
print dataset
# Out:
# <DatasetType with children 'AerosolResults_aerosol_1_aod', 'AerosolResults_aerosol_1_aod_high', 'AerosolResults_aerosol_1_aod_low', 'AerosolResults_aerosol_1_aod_mid', 'AerosolResults_aerosol_1_gaussian_log_param', 'AerosolResults_aerosol_1_gaussian_log_param_apriori', 'AerosolResults_aerosol_1_gaussian_log_param_uncert', 'AerosolResults_aerosol_2_aod', 'AerosolResults_aerosol_2_aod_high', 'AerosolResults_aerosol_2_aod_low', 'AerosolResults_aerosol_2_aod_mid', 'AerosolResults_aerosol_2_gaussian_log_param', 'AerosolResults_aerosol_2_gaussian_log_param_apriori', 'AerosolResults_aerosol_2_gaussian_log_param_uncert', 'AerosolResults_aerosol_3_aod', 'AerosolResults_aerosol_3_aod_high', 'AerosolResults_aerosol_3_aod_low', 'AerosolResults_aerosol_3_aod_mid', 'AerosolResults_aerosol_3_gaussian_log_param', 'AerosolResults_aerosol_3_gaussian_log_param_apriori', 'AerosolResults_aerosol_3_gaussian_log_param_uncert', 'AerosolResults_aerosol_4_aod', 'AerosolResults_aerosol_4_aod_high', 'AerosolResults_aerosol_4_aod_low', 'AerosolResults_aerosol_4_aod_mid', 'AerosolResults_aerosol_4_gaussian_log_param', 'AerosolResults_aerosol_4_gaussian_log_param_apriori', 'AerosolResults_aerosol_4_gaussian_log_param_uncert', 'AerosolResults_aerosol_total_aod', 'AerosolResults_aerosol_total_aod_high', 'AerosolResults_aerosol_total_aod_low', 'AerosolResults_aerosol_total_aod_mid', 'AerosolResults_aerosol_types', 'AlbedoResults_albedo_apriori_o2_fph', 'AlbedoResults_albedo_apriori_strong_co2_fph', 'AlbedoResults_albedo_apriori_weak_co2_fph', 'AlbedoResults_albedo_o2_fph', 'AlbedoResults_albedo_slope_apriori_o2', 'AlbedoResults_albedo_slope_apriori_strong_co2', 'AlbedoResults_albedo_slope_apriori_weak_co2', 'AlbedoResults_albedo_slope_o2', 'AlbedoResults_albedo_slope_strong_co2', 'AlbedoResults_albedo_slope_uncert_o2', 'AlbedoResults_albedo_slope_uncert_strong_co2', 'AlbedoResults_albedo_slope_uncert_weak_co2', 'AlbedoResults_albedo_slope_weak_co2', 'AlbedoResults_albedo_strong_co2_fph', 'AlbedoResults_albedo_uncert_o2_fph', 'AlbedoResults_albedo_uncert_strong_co2_fph', 'AlbedoResults_albedo_uncert_weak_co2_fph', 'AlbedoResults_albedo_weak_co2_fph', 'DispersionResults_dispersion_offset_apriori_o2', 'DispersionResults_dispersion_offset_apriori_strong_co2', 'DispersionResults_dispersion_offset_apriori_weak_co2', 'DispersionResults_dispersion_offset_o2', 'DispersionResults_dispersion_offset_strong_co2', 'DispersionResults_dispersion_offset_uncert_o2', 'DispersionResults_dispersion_offset_uncert_strong_co2', 'DispersionResults_dispersion_offset_uncert_weak_co2', 'DispersionResults_dispersion_offset_weak_co2', 'L1bScSoundingReference_packaging_qual_flag', 'L1bScSoundingReference_retrieval_index', 'L1bScSpectralParameters_max_declocking_factor_o2', 'L1bScSpectralParameters_max_declocking_factor_strong_co2', 'L1bScSpectralParameters_max_declocking_factor_weak_co2', 'L1bScSpectralParameters_rad_mean_spectra_o2', 'L1bScSpectralParameters_rad_mean_spectra_strong_co2', 'L1bScSpectralParameters_rad_mean_spectra_weak_co2', 'L1bScSpectralParameters_rad_stddev_spectra_o2', 'L1bScSpectralParameters_rad_stddev_spectra_strong_co2', 'L1bScSpectralParameters_rad_stddev_spectra_weak_co2', 'L1bScSpectralParameters_snr_o2_l1b', 'L1bScSpectralParameters_snr_strong_co2_l1b', 'L1bScSpectralParameters_snr_weak_co2_l1b', 'L1bScSpectralParameters_spike_eof_bad_colors_o2', 'L1bScSpectralParameters_spike_eof_bad_colors_strong_co2', 'L1bScSpectralParameters_spike_eof_bad_colors_weak_co2', 'Metadata_ARPAncillaryDatasetDescriptor', 'Metadata_AbscoCO2Scale', 'Metadata_AbscoH2OScale', 'Metadata_AbscoO2Scale', 'Metadata_AcquisitionMode', 'Metadata_ActualFrames', 'Metadata_ActualGoodRetrievals', 'Metadata_ActualRetrievals', 'Metadata_AncillaryDataDescriptors', 'Metadata_AscendingEquatorCrossingDate', 'Metadata_AscendingEquatorCrossingLongitude', 'Metadata_AscendingEquatorCrossingTime', 'Metadata_BuildId', 'Metadata_CollectionLabel', 'Metadata_DataFormatType', 'Metadata_EphemerisType', 'Metadata_Eq ...

# %% [markdown]
# Let's select a few variables for geo-rerfencing and plot.

# %%
latitude = dataset['RetrievalGeometry_retrieval_latitude'][:]
longitude = dataset['RetrievalGeometry_retrieval_longitude'][:]
altitude = dataset['RetrievalGeometry_retrieval_altitude'][:]
data =  dataset['RetrievalResults_xco2'][:]

# %% [markdown]
# Cesiumpy supports colormap. To use colormap, it is necessary to scale data values so that they fall in the 0.0 ~ 1.0 range.

# %%
data_min = min(data)
data_max = max(data)
scale = data_max - data_min
# Scale data for colormap.
data_scale = (data - data_min) / scale

# %% [markdown]
# Visualize data with Cesium.

# %%
v = cesiumpy.Viewer()
# Move the view point to the first data point.
v.camera.flyTo((float(longitude[0]), float(latitude[0]), float(altitude[0] * 100000)))
cmap = cesiumpy.color.get_cmap('jet')
v.plot.scatter(longitude, latitude, altitude, color=cmap(data_scale))
# Out:
# <script src="https://cesiumjs.org/Cesium/Build/Cesium/Cesium.js"></script>
# <link rel="stylesheet" href="https://cesiumjs.org/Cesium/Build/Cesium/Widgets/widgets.css" type="text/css">
# <div id="container-4440137808" style="width:100%; height:100%;"><div>
# <script type="text/javascript">
#   var widget = new Cesium.Viewer("container-4440137808");
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.542999268, -38.8446998596, 67.8174362183), point : {pixelSize : 10.0, color : new Cesium.Color(1.0, 0.378358750908, 0.0, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.613601685, -38.7643013, 136.988479614), point : {pixelSize : 10.0, color : new Cesium.Color(1.0, 0.465504720407, 0.0, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.518493652, -38.7650947571, 93.9820556641), point : {pixelSize : 10.0, color : new Cesium.Color(1.0, 0.334785766158, 0.0, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.451324463, -38.3652000427, 142.274246216), point : {pixelSize : 10.0, color : new Cesium.Color(1.0, 0.843137254902, 0.0, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.421905518, -38.3569526672, 133.299453735), point : {pixelSize : 10.0, color : new Cesium.Color(1.0, 0.828612926652, 0.0, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.409957886, -38.3625411987, 138.358932495), point : {pixelSize : 10.0, color : new Cesium.Color(0.781151170145, 1.0, 0.186590765338, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.456161499, -38.2479782104, 119.471061707), point : {pixelSize : 10.0, color : new Cesium.Color(1.0, 0.363834422658, 0.0, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.450119019, -38.2280540466, 121.514389038), point : {pixelSize : 10.0, color : new Cesium.Color(1.0, 0.639796659405, 0.0, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.438720703, -38.2341499329, 118.054008484), point : {pixelSize : 10.0, color : new Cesium.Color(1.0, 0.726942628903, 0.0, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.444015503, -38.2080917358, 118.037010193), point : {pixelSize : 10.0, color : new Cesium.Color(1.0, 0.770515613653, 0.0, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.432632446, -38.2141838074, 119.607833862), point : {pixelSize : 10.0, color : new Cesium.Color(1.0, 0.799564270153, 0.0, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.355834961, -38.1832695007, 115.439941406), point : {pixelSize : 10.0, color : new Cesium.Color(1.0, 0.683369644154, 0.0, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.396728516, -38.1401596069, 121.213233948), point : {pixelSize : 10.0, color : new Cesium.Color(1.0, 0.552650689906, 0.0, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.38508606, -38.1461105347, 117.942047119), point : {pixelSize : 10.0, color : new Cesium.Color(1.0, 0.581699346405, 0.0, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.402130127, -38.1141281128, 117.973800659), point : {pixelSize : 10.0, color : new Cesium.Color(0.907653383934, 1.0, 0.0600885515497, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.390579224, -38.1201477051, 122.998565674), point : {pixelSize : 10.0, color : new Cesium.Color(0.932953826692, 1.0, 0.0347881087919, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.378936768, -38.1261024475, 123.638252258), point : {pixelSize : 10.0, color : new Cesium.Color(1.0, 0.843137254902, 0.0, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.367279053, -38.1319046021, 119.999717712), point : {pixelSize : 10.0, color : new Cesium.Color(1.0, 0.755991285403, 0.0, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.361129761, -38.1118965149, 124.140647888), point : {pixelSize : 10.0, color : new Cesium.Color(0.983554712207, 0.944807552651, 0.0, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.349380493, -38.1176490784, 122.723335266), point : {pixelSize : 10.0, color : new Cesium.Color(1.0, 0.814088598402, 0.0, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.366622925, -38.0860824585, 127.006958008), point : {pixelSize : 10.0, color : new Cesium.Color(0.932953826692, 1.0, 0.0347881087919, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.354980469, -38.0918884277, 126.852401733), point : {pixelSize : 10.0, color : new Cesium.Color(1.0, 0.857661583152, 0.0, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.343231201, -38.0976448059, 124.967941284), point : {pixelSize : 10.0, color : new Cesium.Color(1.0, 0.857661583152, 0.0, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.348800659, -38.0719337463, 128.867706299), point : {pixelSize : 10.0, color : new Cesium.Color(1.0, 0.814088598402, 0.0, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.337051392, -38.0776901245, 127.890197754), point : {pixelSize : 10.0, color : new Cesium.Color(1.0, 0.886710239651, 0.0, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.325134277, -38.083278656, 128.332229614), point : {pixelSize : 10.0, color : new Cesium.Color(1.0, 0.857661583152, 0.0, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.388778687, -38.0280761719, 126.553985596), point : {pixelSize : 10.0, color : new Cesium.Color(1.0, 0.799564270153, 0.0, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.342605591, -38.0519790649, 129.998626709), point : {pixelSize : 10.0, color : new Cesium.Color(0.95825426945, 0.97385620915, 0.00948766603416, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.330871582, -38.0577354431, 133.74961853), point : {pixelSize : 10.0, color : new Cesium.Color(1.0, 0.843137254902, 0.0, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.318969727, -38.0633277893, 132.9140625), point : {pixelSize : 10.0, color : new Cesium.Color(0.996204933586, 0.930283224401, 0.0, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.37121582, -38.0142211914, 135.825088501), point : {pixelSize : 10.0, color : new Cesium.Color(0.895003162555, 1.0, 0.0727387729285, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.359695435, -38.0202484131, 133.283370972), point : {pixelSize : 10.0, color : new Cesium.Color(0.945604048071, 0.9883805374, 0.022137887413, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.336425781, -38.0320205688, 130.772628784), point : {pixelSize : 10.0, color : new Cesium.Color(0.983554712207, 0.944807552651, 0.0, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.324707031, -38.0377807617, 140.904022217), point : {pixelSize : 10.0, color : new Cesium.Color(1.0, 0.872185911402, 0.0, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.312805176, -38.0433731079, 145.240570068), point : {pixelSize : 10.0, color : new Cesium.Color(1.0, 0.814088598402, 0.0, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.376434326, -37.9881591797, 150.950790405), point : {pixelSize : 10.0, color : new Cesium.Color(0.920303605313, 1.0, 0.0474383301708, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.365097046, -37.9942626953, 146.017044067), point : {pixelSize : 10.0, color : new Cesium.Color(0.970904490829, 0.959331880901, 0.0, 1.0)}});
#   widget.entities.add({position : Cesium.Cartesian3.fromDegrees(143.35357666, -38.000289917, 140.05796814), point : {pixelSize : 10.0, color : new Cesium.Color(0.983554712207, 0.94480

# %% [markdown]
# # References
# 1. http://hdfeos.org/zoo/GESDISC/oco2_L2StdND_03945a_150330_B6000_150331024816.h5.py
# 2. http://hdfeos.org/zoo/GESDISC/oco2_L2StdND_03945a_150330_B6000_150331024816.h5.py.png
